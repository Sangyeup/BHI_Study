# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.datasets import load_breast_cancer
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler
# %matplotlib inline

# %%
dataset = load_breast_cancer()
data = dataset['data']
target = dataset['target']

# %%
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(data)
principalDf = pd.DataFrame(data = principalComponents,
                          columns = ['PC 1', 'PC 2'])
target = pd.DataFrame(target, columns=['target'])
target = target.replace(0, 'Normal')
target = target.replace(1, 'Patient')
finalDf = pd.concat([principalDf, target], axis=1)
finalDf
# Out:
#             PC 1        PC 2   target
# 0    1160.142574 -293.917544   Normal
# 1    1269.122443   15.630182   Normal
# 2     995.793889   39.156743   Normal
# 3    -407.180803  -67.380320   Normal
# 4     930.341180  189.340742   Normal
# ..           ...         ...      ...
# 564  1414.126684  110.222492   Normal
# 565  1045.018854   77.057589   Normal
# 566   314.501756   47.553525   Normal
# 567  1124.858115   34.129225   Normal
# 568  -771.527622  -88.643106  Patient
#
# [569 rows x 3 columns]

# %%
fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(1, 1, 1)
ax.set_xlabel('PC 1', fontsize=10)
ax.set_ylabel('PC 2', fontsize=10)
ax.set_title('BRCA PCA', fontsize=10)
targets = ['Normal', 'Patient']
colors = ['r', 'b']
for tgt, color in zip(targets, colors):
    indicesToKeep = finalDf['target'] == tgt
    ax.scatter(finalDf.loc[indicesToKeep, 'PC 1']
              , finalDf.loc[indicesToKeep, 'PC 2']
              , c = color
              , s = 50)
ax.legend(targets)
ax.grid()

# %%
tsne = TSNE(n_components=2)
tsne_result = tsne.fit_transform(data)
tsneDf = pd.DataFrame(data = tsne_result, columns = ['TSNE x', 'TSNE y'])
finalDf = pd.concat([tsneDf, target], axis=1)
finalDf
# Out:
#         TSNE x     TSNE y   target
# 0    -5.352117  27.301888   Normal
# 1    -8.052316  27.965834   Normal
# 2   -11.229487  24.317734   Normal
# 3    14.350249  -8.524030   Normal
# 4   -10.668720  22.022852   Normal
# ..         ...        ...      ...
# 564  -8.062575  29.672970   Normal
# 565 -10.138622  24.570557   Normal
# 566 -21.384686   7.571000   Normal
# 567  -9.392072  26.245522   Normal
# 568  31.424120  19.161419  Patient
#
# [569 rows x 3 columns]

# %%
fig = plt.figure(figsize = (5,5))
ax = fig.add_subplot(1, 1, 1)
ax.set_xlabel('TSNE x', fontsize=10)
ax.set_ylabel('TSNE y', fontsize=10)
ax.set_title('BRCA TSNE', fontsize=10)
targets = ['Normal', 'Patient']
colors = ['r', 'b']
for target, color in zip(targets, colors):
    indicesToKeep = finalDf['target'] == target
    ax.scatter(finalDf.loc[indicesToKeep, 'TSNE x']
              , finalDf.loc[indicesToKeep, 'TSNE y']
              , c = color
              , s = 50)
ax.legend(targets)
ax.grid()

# %%
data = StandardScaler().fit_transform(data)
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(data)
principalDf = pd.DataFrame(data = principalComponents,
                          columns = ['PC 1', 'PC 2'])

target = dataset['target']
target = pd.DataFrame(target, columns=['target'])
target = target.replace(0, 'Normal')
target = target.replace(1, 'Patient')
finalDf = pd.concat([principalDf, target], axis=1)

fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(1, 1, 1)
ax.set_xlabel('PC 1', fontsize=10)
ax.set_ylabel('PC 2', fontsize=10)
ax.set_title('BRCA PCA', fontsize=10)
targets = ['Normal', 'Patient']
colors = ['r', 'b']
for tgt, color in zip(targets, colors):
    indicesToKeep = finalDf['target'] == tgt
    ax.scatter(finalDf.loc[indicesToKeep, 'PC 1']
              , finalDf.loc[indicesToKeep, 'PC 2']
              , c = color
              , s = 50)
ax.legend(targets)
ax.grid()

# %%
tsne = TSNE(n_components=2)
tsne_result = tsne.fit_transform(data)
tsneDf = pd.DataFrame(data = tsne_result, columns = ['TSNE x', 'TSNE y'])
finalDf = pd.concat([tsneDf, target], axis=1)
fig = plt.figure(figsize = (5,5))
ax = fig.add_subplot(1, 1, 1)
ax.set_xlabel('TSNE x', fontsize=10)
ax.set_ylabel('TSNE y', fontsize=10)
ax.set_title('BRCA TSNE', fontsize=10)
targets = ['Normal', 'Patient']
colors = ['r', 'b']
for target, color in zip(targets, colors):
    indicesToKeep = finalDf['target'] == target
    ax.scatter(finalDf.loc[indicesToKeep, 'TSNE x']
              , finalDf.loc[indicesToKeep, 'TSNE y']
              , c = color
              , s = 50)
ax.legend(targets)
ax.grid()

# %%
sum(pca.explained_variance_ratio_)
# Out:
# 0.6324320765155944

# %%
pca = PCA()
principalComponents = pca.fit_transform(data)
pca.explained_variance_ratio_
# Out:
# array([4.42720256e-01, 1.89711820e-01, 9.39316326e-02, 6.60213492e-02,
#        5.49576849e-02, 4.02452204e-02, 2.25073371e-02, 1.58872380e-02,
#        1.38964937e-02, 1.16897819e-02, 9.79718988e-03, 8.70537901e-03,
#        8.04524987e-03, 5.23365745e-03, 3.13783217e-03, 2.66209337e-03,
#        1.97996793e-03, 1.75395945e-03, 1.64925306e-03, 1.03864675e-03,
#        9.99096464e-04, 9.14646751e-04, 8.11361259e-04, 6.01833567e-04,
#        5.16042379e-04, 2.72587995e-04, 2.30015463e-04, 5.29779290e-05,
#        2.49601032e-05, 4.43482743e-06])

# %%
sum(pca.explained_variance_ratio_[:9])
# Out:
# 0.9398790324425355

# %%
principalDf = pd.DataFrame(data=principalComponents)
principalDf_10 = principalDf.loc[:,:9]
tsne_pca_data = principalDf_10
tsne_pca_data = TSNE().fit_transform(tsne_pca_data)
tsneDf = pd.DataFrame(data = tsne_pca_data, columns = ['TSNE x', 'TSNE y'])
target = dataset['target']
target = pd.DataFrame(target, columns=['target'])
target = target.replace(0, 'Normal')
target = target.replace(1, 'Patient')
finalDf = pd.concat([tsneDf, target], axis=1)
fig = plt.figure(figsize = (5,5))
ax = fig.add_subplot(1, 1, 1)
ax.set_xlabel('TSNE x', fontsize=10)
ax.set_ylabel('TSNE y', fontsize=10)
ax.set_title('BRCA TSNE', fontsize=10)
targets = ['Normal', 'Patient']
colors = ['r', 'b']
for target, color in zip(targets, colors):
    indicesToKeep = finalDf['target'] == target
    ax.scatter(finalDf.loc[indicesToKeep, 'TSNE x']
              , finalDf.loc[indicesToKeep, 'TSNE y']
              , c = color
              , s = 50)
ax.legend(targets)
ax.grid()
